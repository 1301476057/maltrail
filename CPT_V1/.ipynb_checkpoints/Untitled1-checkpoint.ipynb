# %%
import pandas as pd
import numpy as np
import read_data
import warnings
import first_clustering
import cal_smilar
import match

import tldextract

import altair as alt
from vega_datasets import data
# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
result = pd.read_csv('result.csv')
valid = pd.read_csv('valid.csv')
train = pd.read_csv('test.csv')
safe_host = pd.read_csv('safe_host.csv',names=['host'])

# %%
def get_host(x):
    val = tldextract.extract(x)
    return val.domain + '.' + val.suffix

# %%
result['original_host'] = result['original_host'].apply(lambda x:get_host(x))

# %%
print('result: '+ result['ip_24'].unique())
print('valid: '+ valid['ip_24'].unique())
print('train: '+ train['ip_24'].unique())
# Out:
# ['result: 23.15.8' 'result: 104.96.220' 'result: 15.72.238' ...
#  'result: 54.86.50' 'result: 54.173.232' 'result: 52.86.117']
# ['valid: 23.36.33' 'valid: 172.82.206']
# ['train: 172.82.206' 'train: 23.36.33']

# %%
test_ip_1 = valid['ip_24'].unique()
test_ip_2 = [ip for ip in result['ip_24'].unique() if ip not in test_ip_1]

# %%
result = result[result['ip_24'].isin(test_ip_2)]
print(len(result))
# Out:
# 47852

# %%
ans = result[(result['y']=='safe')]
ans_host = ans['original_host'].unique()
safe_host = list(safe_host['host'].values)
same_host = list(set(safe_host)&set(ans_host))
result = result[~result['original_host'].isin(same_host)]

# %%
source = result['ip_24'].value_counts().reset_index().rename(columns={'ip_24': 'count', 'index': 'ip_24'})
bars = alt.Chart(source).mark_bar(color='blue').encode(
    x='ip_24',
    y='count:Q',

)
text = bars.mark_text(
    align='center',
    baseline='middle',
#     dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='count:Q'
)
(bars + text).properties(title="Counts of ip_24", width=700,height=500)

# %%
x = 0.12
print(len(result[(result['y']=='safe')|(result['y']=='malicious')]))
print("safe dis > " + str(x) + " :" + str(len(result[(result['y']=='safe')&(result['dis']>x)])))
print("safe dis > " + str(x) + " label=1:" +  str(len(result[(result['y']=='safe')&(result['dis']>x)&(result['label']==1)])))
print("safe dis <= " + str(x) + " :" +  str(len(result[(result['y']=='safe')&(result['dis']<=x)])))
print("safe dis <= " + str(x) + " label=1:" +  str(len(result[(result['y']=='safe')&(result['dis']<=x)&(result['label']==1)])))
print("malicious dis > " + str(x) + " :" +  str(len(result[(result['y']=='malicious')&(result['dis']>x)])))
print("malicious dis > " + str(x) + " label=1:" +  str(len(result[(result['y']=='malicious')&(result['dis']>x)&(result['label']==1)])))
print("malicious dis <= " + str(x) + " :" +  str(len(result[(result['y']=='malicious')&(result['dis']<=x)])))
print("malicious dis <= " + str(x) + " label=1:" +  str(len(result[(result['y']=='malicious')&(result['dis']<=x)&(result['label']==1)])))
# Out:
# 3014
# safe dis > 0.12 :2029
# safe dis > 0.12 label=1:75
# safe dis <= 0.12 :80
# safe dis <= 0.12 label=1:63
# malicious dis > 0.12 :403
# malicious dis > 0.12 label=1:325
# malicious dis <= 0.12 :502
# malicious dis <= 0.12 label=1:3

# %%
TP = 502 + 325
FN = 403-325
FP = 80+75
TN = 2029-75

# %%
P = TP / (TP + FP)
R = TP / (TP + FN)
F1 = 2*TP / (2*TP + FP + FN)
auc  = (TP + TN) / (TP + FN + FP + TN)
print(P,R,F1,auc)
# Out:
# 0.8421588594704684 0.9138121546961326 0.8765235824059353 0.9226940942269409

# %%
### 
    精确率            找回率               F1_Score          准确率
0.1
    0.842374616171955 0.9093922651933701 0.8746014877789585 0.9216987392169874
0.12
    0.8421588594704684 0.9138121546961326 0.8765235824059353 0.9226940942269409
    
0.15
    0.683429513602638 0.9160220994475138 0.7828139754485364 0.847378898473789
0.2
    0.3733751680860601 0.9204419889502763 0.53125 0.5138888888888888
0.25
    0.29537729435757987 0.9602209944751381 0.45178060826618144 0.30026542800265427
    
###

# %%
6831+1899+401+278+556
# Out:
# 9965

# %%
ans = result[(result['y']=='safe')]
ans_host = ans['original_host'].unique()
safe_host = list(safe_host['host'].values)
same_host = list(set(safe_host)&set(ans_host))
result = result[~result['original_host'].isin(same_host)]

# %%
len(safe_host)
# Out:
# 1086790

# %%
len(result[(result['y']=='safe')])
# Out:
# 3428

# %%
result[(result['y']=='safe')&(result['dis']<=x)]['original_host'].unique()
# Out:
# array(['www.hp.com', 'www8.hp.com', 'rps-svcs.sun.com',
#        'ocsp.digicert.com', 'www.jildorshoes.com', 'translate.google.com',
#        'images.scanalert.com', 'www.google.com', 'um.simpli.fi',
#        'track.eyeviewads.com', 'rp.gwallet.com', 'l.betrad.com',
#        'www.preemiestore.com', 's2.symcb.com', 'login.live.com',
#        'global.fncstatic.com', 'pagead2.googlesyndication.com',
#        'static.adsafeprotected.com', 'dt.adsafeprotected.com',
#        'ds-aksb-a.akamaihd.net', 'cdn.cxense.com', 'idsync.rlcdn.com',
#        'a.postrelease.com', 'brightcove.vo.llnwd.net', 'ap.lijit.com',
#        'ad.doubleclick.net', 'www.microsoft.com', 'vop.sundaysky.com',
#        'cm.g.doubleclick.net', 'web.mit.edu', 'download.mozilla.org',
#        'www1.cbn.com', 'www.cbn.com', 'metrics.brightcove.com',
#        'c.brightcove.com', 'us.fluke.com', 'www.ire.org',
#        'www.gstatic.com', 'www.msn.com', 'o.aolcdn.com',
#        'widgets.outbrain.com', 'cdn.taboola.com', 'ocsp.usertrust.com',
#        'ocsp.comodoca.com', 'ocsp.globalsign.com', 'router.infolinks.com',
#        'www.newhealthguide.org', 'www.photojoiner.net',
#        'www.andhrajyothy.com', 'www.oracle.com', 'www.ltn.com.tw',
#        'www.java2s.com', 'tutorials.jenkov.com', 'www.emjcd.com',
#        'ieeexplore.ieee.org', 'www.prothom-alo.com', 'www.hm.com',
#        'www.reverso.net', 'www.investopedia.com', 'www.ndtv.com',
#        'www.sapo.pt', 'x.bidswitch.net', 'www.tebyan.net', 'www.espn.com',
#        'aglobal.go.com', 'www.kijiji.ca', 'www.porn.com',
#        'www.indeed.com', 'archive.eclipse.org', 'web.b.ebscohost.com',
#        'search.ebscohost.com', 'www.livejournal.com', 'www.goal.com',
#        'tags.bkrtx.com', 'ad.360yield.com', 'p.adsymptotic.com',
#        'sync.teads.tv', 'ib.mookie1.com', 'www.microsoftstore.com',
#        'uae.souq.com', 'www.y8.com', 'www.dostor.org', 'imgs.sapo.pt',
#        'www.milliyet.com.tr', 'info.puppetlabs.com', 'www.intuit.com',
#        'www.momoshop.com.tw', 'www.dailymotion.com',
#        'www.androidcentral.com', 'px.owneriq.net', 'www.game-debate.com',
#        'www-01.ibm.com', 'www.android.pk', 'platform.tumblr.com',
#        's.gravatar.com', 'tools.android.com', 'translate.google.ca',
#        'www.tutorialspoint.com', 'i474.photobucket.com', 'www.kompas.com',
#        'a.dilcdn.com', 'tredir.go.com', 'tag.researchnow.com',
#        'secure-us.imrworldwide.com', 'www.bing.com', 'dx.doi.org',
#        'www.androidhive.info', 'www.jmlr.org', 'oap.accuweather.com',
#        'ac.els-cdn.com', 'www.mi.com', 'web.a.ebscohost.com',
#        'www.mkyong.com', 'ak.sail-horizon.com', 'i.w55c.net',
#        'contextual.media.net', 'pixel.everesttech.net', 't.dtscout.com',
#        'www.bbc.com', 'dl.acm.org', 'shop.nordstrom.com',
#        'www.costco.com', 'www.win.tue.nl', 'link.theplatform.com',
#        'www.sberbank.ru', 'photos1.blogger.com', 'mathworld.wolfram.com',
#        'www.1tv.ru', 'us.weibo.com', 'passport.tianya.cn',
#        'gazeta.hit.gemius.pl', 'jnetpcap.com', 'v2.zopim.com',
#        'c.amazon-adsystem.com', 'app.dictionary.com',
#        'as.casalemedia.com', 'magnetic.t.domdex.com',
#        'partners.cmptch.com', 'oystatic.ignimgs.com',
#        'www.timhortons.com', 'wow.zamimg.com', 'www.depesz.com',
#        'research.microsoft.com', 'store.steampowered.com',
#        'cdn.akamai.steamstatic.com', 'www.clear-lines.com',
#        'platform.twitter.com', 'ppa.launchpad.net'], dtype=object)

# %%
safe_host = pd.read_csv('safe_host.csv',names=['host'])
safe_host = list(safe_host['host'].values)

# %%
safe_host = pd.Series(safe_host)

# %%
safe_host.to_csv('safe_host_add.csv',index=False)

# %%
safe_host
# Out:
# ['shengen-visas.ru',
#  'neilmurraydesign.co.uk',
#  'princeclassified.com',
#  'pengke.com',
#  'central-ppk.ru',
#  'aricent.com',
#  'dramaqu.net',
#  'limitnetwork.com',
#  'spytravellers.com',
#  'france5.fr',
#  'itr2010.org',
#  'leho.com',
#  'unicart.com',
#  'greetzap.com',
#  'hmveng.co.uk',
#  'chinaregistry.org.sg',
#  'scandinaviawolf.com',
#  'corepacks.com',
#  '200baliv.org',
#  'bloggerbuster.com\r\r\n',
#  'npmjs.com',
#  'loterianacional.gob.do',
#  'cos25tv.com',
#  'stroybud.com',
#  'premiosjuventud.com',
#  'puskesmasmakale.blogspot.com',
#  'safaraval24.ir',
#  'ar.estate',
#  'britanico.edu.pe',
#  'maclickmoneys.com',
#  'polliana.com',
#  'eltra-trade.com',
#  'ekmpowershop.com\r\r\n',
#  'goodforvn.com',
#  'igrul-ka.ru',
#  'popdust.com',
#  'caminandoentredinosaurios.com',
#  'amoma.com',
#  'namdonews.com',
#  'ilglobo.com.au',
#  'importgenius.com',
#  'hollywoodhistoricphotos.com',
#  'medik-ekt.ru',
#  'e-stradivarius.net',
#  'govexam.in',
#  'azonitblog2.wordpress.com',
#  'icanportal.org',
#  'denx.su',
#  'manggear.com',
#  'vidtubeporn.com',
#  'xn--12cas3c2av3m3a0g7c.com',
#  'sharikna.me',
#  'acorn.tv',
#  'qqjay.com\r\r\n',
#  'xn----8sbp3abdbfk9f.com',
#  'iqmac.ru',
#  'omsk.comuf.com',
#  'gluesale.ru',
#  'payday.su',
#  'madyart.ru',
#  'apefeito.com.br',
#  'nihanyarkent.com',
#  'bengalfoodmart.com',
#  'updigo.com',
#  'katariagroup.co',
#  'wexphotographic.com\r\r\n',
#  'supermeydan.net',
#  'autofanat.com.ua',
#  'freelibraco.in',
#  'chistilka.ru',
#  'daneshgahezendegi.com',
#  'mpdnlu.ac.in',
#  'vulcan-club-cazino.com',
#  'sadaqift.com',
#  'jobium.net',
#  'darkparadise.eu',
#  'snmvl.com',
#  'intim76.com',
#  'indianterrain.com',
#  'dardirouz.persianblog.ir',
#  'xploitlab.com',
#  'pckosar.com',
#  'pervoistok.lv',
#  '3dinnet.com\r\r\n',
#  'ohiocamper.com',
#  'brickowl.com',
#  'makelogoonlinefree.com',
#  'master-x.com\r\r\n',
#  'productboard.com',
#  'autodesk.fr',
#  'chemihui.com.cn\r\r\n',
#  'uvimex.com.mx',
#  'michellejdesigns.com',
#  'parcelapp.net',
#  'by1.by',
#  'bepilatesyoga.com',
#  'kinja-img.com\r\r\n',
#  'leclubargent.com',
#  'roqoon.com',
#  'flyone.md',
#  'storeland.ru',
#  'trungtamthietbidiencongnghiep.vn',
#  '4lifemarket.ru',
#  'jobsfeed.pk',
#  'adnsl.com',
#  'fawaz.com',
#  'forosdelavirgen.org',
#  'hit-info.ru',
#  'smtamilnovels.com',
#  'winnexus.com',
#  'redpack.ir',
#  'galataart.com',
#  'onekorea.ru',
#  'ptrvipclub.com',
#  'kinotan.su',
#  'simplepatwa.wordpress.com',
#  'unfunnel.com',
#  'legacysgold.com',
#  'altaynews.kz',
#  'patagonia.com\r\r\n',
#  'gwpneus.com.br',
#  'circus-vladivostok.ru',
#  'drjunker.org',
#  'superamostras.com\r\r\n',
#  'lanecc.edu',
#  'rankedgaming.com',
#  'breakwatersurf.com',
#  'foxize.com',
#  'na-donyshke.ru',
#  'theancientbabylonians.com',
#  'zambianme.com',
#  'makinecim.com',
#  'csp-nn.ru',
#  'mezo.me\r\r\n',
#  'fashionlife33.ru',
#  'serupting.net',
#  'petergriffin.com',
#  'mywowbb.com',
#  'soniresources.com',
#  'lbpweaccess.com',
#  'bajarfacebook.com',
#  'avisos-colombia.com',
#  'deival909.ru',
#  'ohhhey.com',
#  'gold-master.com.ua',
#  'mis-psimada.org',
#  'cheron-mebel.ru',
#  'creativedisc.com',
#  'northsydneybears.com.au',
#  'groiro.by',
#  'go-solid.be',
#  'laikasnamams.lt',
#  'delta-search.com',
#  'taxi-money.top',
#  'jobssup.com',
#  'jessicalarrew.com',
#  'pickywallpapers.com',
#  'fotech.me',
#  'mac-mix.blogspot.com',
#  'rvhi-hildesheim.de',
#  'dnalounge.com',
#  'ispydiy.com',
#  'pharco-corp.com',
#  'jimsautosalesla.com',
#  'pikrosta.com',
#  'first-school.ws',
#  'mgtsystems.com',
#  'kevinbrkal.com',
#  'germanforenglishspeakers.com',
#  'jobsstart.com',
#  'kidsout.ru',
#  'globalacademicinstitute.com',
#  'tubecontext.com',
#  'mystylie.com',
#  'productreviewaccess.weebly.com',
#  'pavothemes.com',
#  '1look4.com\r\r\n',
#  'mersifile.com',
#  'fluidstack.io',
#  'studynowpk.com',
#  'seated.com.au',
#  'beelzebubclub.blogspot.com',
#  'spiriteo.com',
#  'mszd.net',
#  'dasding.de',
#  'reserveamerica.com',
#  'advance-club.org',
#  'hram-tih.ru',
#  'ancientegypt.co.uk',
#  'bigfuntrip.com',
#  'rentacarss.com',
#  'erowid.org\r\r\n',
#  'itesco.sk',
#  'it-finance.com',
#  'ma2web.com',
#  'vitmess-api.herokuapp.com',
#  'gidasanayim.com',
#  'sendmsg.co.il',
#  'persien.ru',
#  'prestigedeco.sn',
#  'yamchops.com',
#  'goranlazarevski.com',
#  'depositincome.com',
#  'fasttrack.in',
#  'die-smarte-werkstatt.de',
#  'parvus.nl',
#  'maseke.net',
#  'kttc.com',
#  'daewoo-shop.com',
#  'doikham.ac.th',
#  'poirotonline.com',
#  'docusign.com\r\r\n',
#  'juegosonline.name',
#  'alareficargo.com',
#  'realteenvideoclub.com',
#  'webizmedia.com',
#  'spsmayurvihar.com',
#  'diwis.ru',
#  'naturahali.com.tr',
#  'obakilcadir.com',
#  'ahmadyusufdenasri.blogspot.com',
#  'integrity-events.com',
#  'tuhocielts9.vn',
#  'biodic.net',
#  'skameyka-sadovaya.com.ua',
#  'internetkapitaene.de\r\r\n',
#  'agromafia.com',
#  'novizki.com',
#  'unige.ch',
#  'thehut.com\r\r\n',
#  'payonline.ru',
#  'novodev.msk.ru',
#  'cornwall.gov.uk',
#  'sgp-studio.ru',
#  'afra-tech.ir',
#  'spselca.org',
#  'travian.in',
#  'unam.edu.pe',
#  'thetravelpockets.com',
#  'devenirplusefficace.com',
#  'eco-mebli.net',
#  'fujitsu-news.com',
#  'floradoc.com',
#  'shahreza.info',
#  'elarna.net',
#  'prolink.pl/user/money',
#  'discogs.com\r\r\n',
#  'guiltymother.co.uk',
#  'atelier-caviar.ru',
#  'programminghints.com',
#  'dobisell.com',
#  'blueridgeknives.com',
#  'anyperk.com',
#  'imaginahome.com',
#  'animejs.com',
#  'cirquedusoleil.com',
#  'kommunity.com',
#  'devstrick.com',
#  'executivesearchdefined.com',
#  'pharmaveda.com',
#  'toshu.cn',
#  'ledinhmmo.com',
#  'pstgu.ru',
#  'haritane.com',
#  'mangakita.net',
#  '3btechpro.com',
#  'shamela.ws',
#  'bandnewsfm.com.br',
#  'charivne.info',
#  'plantpowerpets.com.au',
#  '11wickets.com',
#  'solutionprojob.info',
#  'deco.fr\r\r\n',
#  'ebanksepah.ir',
#  'advertgallery.com',
#  'researchthai.com',
#  'knsitsolutions.com',
#  'latinobobesponja.blogspot.com',
#  'ecoblog.pro',
#  'sanaata.com',
#  'ta360.cn',
#  'gospotainment.com',
#  'tonite.dance',
#  'calplate.com',
#  'msbsolutions.com.au',
#  'vkstorm.ru',
#  'linkcentre.com\r\r\n',
#  'enskysms.com',
#  'oneclickads.in',
#  'rich98.com\r\r\n',
#  'podruga.uz',
#  'fap2xxx.com',
#  'improgrammer.net',
#  'worldofukes.co.uk',
#  'callfutur.com',
#  'cheats-minecraft.com',
#  'highkey.cloud',
#  'pptfile.ir',
#  'thinkvidya.com',
#  'anugrah-argon.com',
#  'part710.online',
#  'africaitexpo.ma',
#  'inspirit.net.in',
#  'hohodelhi.com',
#  'sterils.ru',
#  'enthus1ast.com',
#  'tintuc.com.vn',
#  'sdi-muenchen.de',
#  'bekas.com\r\r\n',
#  'imagescomplete.xyz',
#  'nextel.com.mx',
#  'citios.io',
#  'tafun.info',
#  'freakfonts.com',
#  'likehamster.ru',
#  'vppgamingnetwork.com',
#  'spbrb.ru',
#  'bluejeans-my.sharepoint.com',
#  'caclubindia.com',
#  'hawaii-kirillovka.com',
#  'kartoteka.ru',
#  'originally-mimi.tumblr.com',
#  'spshospitals.com',
#  'templatep2p.com\r\r\n',
#  'alex-brab.livejournal.com',
#  'coffeeinsta.com',
#  'filmtraining.mb.ca',
#  'icoiact.org',
#  'anekamakalah.com',
#  'abc-lounge.com',
#  'omnifinder.com',
#  'bitorb.com',
#  'bbslinks.pw',
#  'zonemaker.com',
#  'libnn.ru',
#  'storacingproducts.com',
#  'rmsothebys.com',
#  'blogchamsoc.com',
#  'followtheview.com',
#  'ytadblock.org',
#  'reoptimize.io',
#  'emploikom.com',
#  'lovethread.bigcartel.com',
#  'haivl.tv\r\r\n',
#  'reshalka.com',
#  'ahlinyalogo.com',
#  'onlinetravelinsurance.com.au',
#  'ciputraentrepreneurship.com\r\r\n',
#  'fsjes-settat.ma',
#  'bddk.org.tr',
#  'mergoo.ru',
#  'paintnet.ru',
#  'r7il.com',
#  'kabinet-fss.ru',
#  'thpthoavang.edu.vn',
#  'zuari-furniture.com',
#  'czechian.net',
#  'referat7.ru',
#  'yazdtablet.ir',
#  'yadegarchick.ir',
#  'businessadministration.win',
#  'dealsofamerica.com',
#  '9e2015smpn1patikraja.blogspot.com',
#  'coolstuffinterestingstuffnews.com',
#  'mypremium.store',
#  'govciooutlook.com',
#  'datenkeller.net',
#  'naturalis.nl',
#  'bellazon.com',
#  'poliana.org',
#  'sex21.cz',
#  'fredericksburg.com',
#  'skoltech.ru',
#  'wpdailythemes.com',
#  'bersaglio.ru',
#  'throwflame.com',
#  'lurrker.com',
#  'thehealthypinoy.com',
#  'votetochai-shop.ru',
#  'syrianproducts.ru',
#  'ebooks-share.net',
#  'hockeytransformation.com',
#  'privitay.com.ua',
#  'materibahasaarabkomplit.blogspot.com',
#  'tbd.my',
#  'hairwiki.ru',
#  'ethico.com.au',
#  'gizmola.com',
#  'dulichthegioionline.blogspot.com',
#  'sqlserverlearner.com',
#  'dantotsu.jp',
#  'eflowers.gr',
#  'ba-works.com',
#  'fahrplan-online.de',
#  'myaccountaccess.com\r\r\n',
#  'insidea.net',
#  'biradm.ru',
#  'stavbaeu.cz',
#  'shorouknews.com\r\r\n',
#  'fashionicism.jimdo.com',
#  'samator.com',
#  'ferradurahotel.com.br',
#  'hackers.co.kr',
#  'canoodlen.blogspot.com',
#  'expedino.com',
#  'simfedretail.com',
#  'dena.com',
#  'sellhealth.com',
#  'mprest.com',
#  'stikesyahoedsmg.ac.id',
#  'notebooks.com',
#  'newsroom.de',
#  'weberia.ru',
#  'vaalstudenthousing.co.za',
#  'northstarmall.com',
#  'snformatuka.blogspot.com',
#  'vertical-innovation.com',
#  'amplifr.com',
#  'dimpletravel.com',
#  'nanmeebooks.com',
#  'ippknsu.ru',
#  'tsonline.forumvi.com',
#  'image-gmkt.com',
#  'xiaomi-mi.us',
#  'brindas.com.sg',
#  'reedexpo.co.jp',
#  'ozhairandbeauty.com',
#  'logos-group.ru',
#  'richkids.me',
#  'bevmaxoffice.com',
#  'iranpooshak.com',
#  'lightsup.co.nz',
#  'wcctv.co.za',
#  'pisexy.me',
#  'thechamberlainnyc.com',
#  'linnea-finnskogen.no',
#  'healthyfitteam.website',
#  'wela.online',
#  'autolife86.ru',
#  'yala2.go.th',
#  'zoonoapt.net',
#  'termgame.com',
#  'virallistbuilderplus.com',
#  'wrenchsp.com',
#  'healtheg.com',
#  'sylt-travel.de',
#  'entotin.xyz',
#  'mearning.com',
#  'vintageandchicblog.com',
#  'balkantelekom.net',
#  'profilepic.ir',
#  'astig.ph',
#  'vibrant-wellness.com',
#  'mentores.com.br',
#  'avasoft.co',
#  'cakebread.co.za',
#  'dealsea.com\r\r\n',
#  'hotgirlclub.com',
#  'aearibbonmics.com',
#  'barryfischetto.com',
#  'cleverlysimple.com',
#  'kientrucsuhcm.com',
#  'bms.mr',
#  'seeksghosts.blogspot.com',
#  'netinfo24.pl',
#  'sumchic.com',
#  'domnika.ru',
#  'egeyurt.com.tr',
#  'toysr.ru',
#  'swanstatistics.com',
#  'kunciinggrisweb.wordpress.com',
#  'bindaaslo.com\r\r\n',
#  'customerparadigm.com',
#  'xxx3.pro',
#  'job4u.ae',
#  'acbnewsonline.com.au\r\r\n',
#  'kinotan.online',
#  'npvstaffing.com',
#  'tehnobiznes.ru',
#  'xiangkaixin.com',
#  'themooncat.com',
#  'vozenred.com',
#  'modernacompartilha.com.br',
#  'thrustzone.com',
#  'bor74.ru',
#  'pictures-of-cats.org',
#  'nombra.me',
#  'hilan.co.il',
#  'fundingportal.com',
#  'golsetan.com',
#  'almudi.org',
#  'vinsep.com',
#  'jagoanmovies.blogspot.com',
#  'ryaninternational.org',
#  'staywellsolutionsonline.com',
#  'banabi.com',
#  'luxup.ru',
#  'clickmeter.com',
#  'memeorandum.com',
#  'afroland-9i9song.blogspot.com',
#  'baiducontent.com',
#  'chaduo.com',
#  'chopracentermeditation.com',
#  'tempr.email',
#  'jabuka.tv',
#  'econedlink.org',
#  'programmed.com.au',
#  'digihamkar.com',
#  'smriti.com',
#  'satpro.by',
#  'mesalva.com',
#  'midasforex.com',
#  'quynhltd.blogspot.com',
#  'engageandgrow.eu',
#  'live-servers.net\r\r\n',
#  'logon.lt',
#  '10best.com',
#  'asiarussia.ru',
#  'arabamericannews.com',
#  'tathagataonline.com',
#  'ashokau.org',
#  'lukasteknoloji.com',
#  'israelgreece.com',
#  'visaexpress.asia',
#  'mitinfo.ru',
#  'misuto.myshopify.com',
#  'mobile-monitoring.ru',
#  'simvoly.com',
#  'animaxvid.com',
#  'enjoylife.fun',
#  'youtubeppp.com',
#  'prizyv.tv',
#  'qbrex-me.com',
#  'comforttown.com.ua',
#  'minihorse-russia.ru',
#  'ventasbot.com',
#  'nodud.com',
#  'teaserfast.ru',
#  'hax.co.id',
#  'aads.us',
#  'akanopw.com',
#  'webcomicz.com',
#  'layarindo21.com',
#  'couponhives.com',
#  'matro-luxe.dp.ua',
#  'ukhuwahanakkuliah.com',
#  'madlifes.com',
#  'oisixradaichi.co.jp',
#  'merckgroup.com',
#  'dramamlky.com',
#  'overcome.com.br',
#  'fobos-avto.ru',
#  'zoldpontpizza.hu',
#  'vehementtools.com',
#  'asistbrok.com',
#  'wearemiq.com',
#  'futuretech-iq.com',
#  'mitula.ma',
#  'train-us.com',
#  'westerndental.com',
#  'courtesychev.com',
#  'invest-melitopol.gov.ua',
#  'i-p-t.ru',
#  'nutkase.com',
#  'raz-kids.com',
#  'bandwidthplace.com',
#  'ditshegomedia.co.za',
#  'hideoutnow.com',
#  'dgm-india.com',
#  'sidirodromikanea.blogspot.com',
#  'nakitel.com',
#  'waocp.com',
#  'dubaivartha.com',
#  'opencalls.co',
#  'banksoaljember.blogspot.com',
#  'servis24.cz',
#  'nobel-168.com',
#  'cadenaunionradio.com',
#  'visa724.com',
#  'rkdj.in',
#  'tecnicocerca.com',
#  'bangkokshotels.com',
#  'nkw05790.wordpress.com',
#  'xraycompany.ru',
#  'gazetekspres.com',
#  'riversidesheriff.org',
#  'investfunds.ru',
#  'a2zp30.net',
#  'arizonafootballonline.net',
#  'crewlounge.center',
#  'wbdg.org',
#  'utbbs.net',
#  'irinabelova.ru',
#  'pcspecialist.it',
#  'hafidahhanumsite.wordpress.com',
#  'cx-lab.ru',
#  'ebpbolivia.org.bo',
#  'drudgereport.com\r\r\n',
#  'reklama-web.com',
#  'motion.co.id',
#  'editorialrove.com',
#  'ecommercephotographyindia.com',
#  'thehappinessdiet.com',
#  'ayurvedadom.com',
#  'learntoday.info',
#  'cannontrading.com',
#  'eneoia.com',
#  'getpaint.net\r\r\n',
#  'technobase.online',
#  'thewebquest.com',
#  'uaudio.com',
#  'mp3clan.net\r\r\n',
#  'brightestgames.com',
#  'thehackerwithin.com',
#  'welight.co',
#  'snf.org',
#  'businessseek.biz',
#  'shlkolkata.com',
#  'collegegreenlight.com',
#  'botsupply.ai',
#  'thexploretravel.com',
#  'jobhabesha.com',
#  'etna-service.by',
#  'j.am',
#  'cheapfavorshop.com',
#  'mobotoos.com',
#  'naturalvet.com.au',
#  'novomoskovsk-rada.gov.ua',
#  'santafesouthwestgrill.com',
#  'medispatechnology.ru',
#  'fns-lk-kabinet.ru',
#  '1poortopedii.ru',
#  'garrisoncollection.com',
#  'ohnopodcast.com',
#  'technology-in-business.net',
#  'dibujoscolorear.org',
#  'evergreen-sms.com',
#  'lidl.at',
#  'univ-argent.fr',
#  'ezadar.hr',
#  'tubeninja.net',
#  'telecomcredit.co.jp',
#  'malakaltawouk.com',
#  'hey-alex.fr',
#  'ceylanticaret.com',
#  'sport-hypnosis.com',
#  'jatik.com',
#  'megaproxy.com',
#  'gwyou.com',
#  'postformika.ru',
#  'royalcanin.es',
#  'invat.ru',
#  'huaweicodecalculator.com',
#  'ibsutah.com',
#  'foodrevolution.org',
#  'transfix.io',
#  'aryabaniran.ir',
#  'ya-mi.org',
#  'klashaber.com',
#  'messer.sk',
#  'rojadirectaplus.com',
#  'mojeek.com',
#  'dikbud.go.id',
#  'asiancommunitynews.com',
#  'riseupsummit.ru',
#  'livesport4u.com',
#  'download-literature-pdf-ebooks.com',
#  'laura-ashley.com.ua',
#  'shopievo.com',
#  'travelerbase.com',
#  'schoolmedia.id',
#  'curvefever.io',
#  'nobissalud.com',
#  'islam-portal.ru',
#  'chernomorsk.news',
#  'fashionablylatent.com\r\r\n',
#  'automotiveforums.com',
#  'qrserver.com',
#  'wildearth.com.au',
#  'nevinbakerymachines.in',
#  'studienkolleg-bochum.de',
#  'i-run.fr',
#  'havana.ru',
#  'nrcresearchpress.com',
#  'smart-hr.com.ua',
#  'zdorovvsegda.pw',
#  'workbot.cl',
#  'rblogger.ru',
#  'biotopic.myshopify.com',
#  'angesgardiens.co',
#  'evonews.ru',
#  'giperton-med.ru',
#  'prelest-prof.ru',
#  'eurogold.ua',
#  'tricitytravel.com',
#  'vape.uz',
#  '4tyayinevi.com',
#  'police.ge',
#  'inflottravel.ru',
#  'fotograf.com.tr',
#  'endo.id',
#  'vbasoftware.com',
#  'telvecit.com',
#  'visiativ-industry.fr',
#  'playsearchnow.com',
#  'silapasart.com',
#  'reeform.ru',
#  'yushkevich.livejournal.com',
#  'max1net.com',
#  '80stees.com',
#  'fiatko.com',
#  'talkwidtech.com',
#  'bridgemillneurological.com',
#  'interaint.com',
#  'grupotombrasil.com.br',
#  'belapb.by',
#  'penlawak.blogspot.com',
#  'happylife.university',
#  'dailidis.gr',
#  'happyfund.or.kr',
#  'cildermansolutions.com',
#  'tresorit.com',
#  'ucld.us',
#  'imda.gov.sg',
#  'migna.ir',
#  'glavm.ru',
#  'duoic.com',
#  'fortnitefa.ir',
#  'yuyoz.com',
#  'terra-credit.com',
#  'dryicon.com',
#  'mh4g.org',
#  'nexoneu.com\r\r\n',
#  'relt.eu',
#  'oswpg.com',
#  'insuranceopedia.com',
#  'pingomatics.com',
#  'rex-m.ru',
#  'komtell.com',
#  'addmustard.com',
#  'nzsale.com',
#  'alexricwald.fr',
#  'goldfishka64.com',
#  'sdushorhockey.by',
#  'thegripclub.com',
#  'ilansahibi.com',
#  'ledokosmos.gr',
#  'dshnm.at.ua',
#  'jagocomilla.com',
#  'aklabs.com',
#  'amazonistas.com',
#  'tarasalviaschool.wordpress.com',
#  'gkto.ru',
#  'roller.de',
#  'tkb-net.jp',
#  'wisesnacks.com',
#  'packit-gma.com',
#  'sap-press.com',
#  'thanganat.com',
#  'umasscs.net',
#  'desertschools.org',
#  'thaarakam.com',
#  'autovirage.by',
#  'livingmaronite.com',
#  'allaboutstlucia.com',
#  'namcomfg.com',
#  'onairlogbook.com',
#  'agir-reussir.fr',
#  'archnews.ir',
#  'digitalworldpanel.com',
#  'dasspackersnmovers.com',
#  'lapcameraquan5.com',
#  'autodepo.ru',
#  'digitalversus.com\r\r\n',
#  '3abank.cn',
#  'coinclub.global',
#  'bedsider.org',
#  'looppng.com',
#  'bsideslisbon.org',
#  'sportique.ru',
#  'aqua-mechanica.ru',
#  'lumos22.info',
#  'goodzonehotel.com.ua',
#  'momentapharma.com',
#  'juliadavidian.com',
#  'onceokuloncesi.com',
#  'p0o.ru',
#  'stozabot.com',
#  'halong-bay-tours.com',
#  'zipstore.ru',
#  'infrasofttech.com',
#  'borginon.be',
#  'albislam.com',
#  'csp.edu',
#  'drsnysvet.cz',
#  'protesto.com.br',
#  'fotki.info',
#  'ankurjadhav.com',
#  'scholl.com.tr',
#  'churacos.com',
#  'ican.md',
#  'americaneagle.com',
#  'edgemedianetwork.com',
#  '100120.ir',
#  'sport-school86.io.ua',
#  'bodyboardking.com',
#  'ispeak.cn',
#  'download-yt-mp3.top',
#  'drsemna.com',
#  'thebrag.com',
#  'kia.kiev.ua',
#  'babybus.cn\r\r\n',
#  'samovensdemo.com',
#  'desiserialstv.org',
#  'mobiloil.com',
#  'couplegroup.com',
#  'thexquisitedge.com',
#  'fillip.co',
#  'nicolette.ro',
#  'iboe.com',
#  'mymoneysouq.com',
#  'gospogroove.com',
#  'korabia.com\r\r\n',
#  'hellofaparty.com',
#  'intellicus.com',
#  'atu.kz',
#  'cardiped.net',
#  'lsua.edu',
#  'insecret.com.ua',
#  'lw-news.com',
#  'epys.com.co',
#  'milfsexmaturemom.com',
#  'xn--80adi3bg6g.com',
#  'avppark.com',
#  'seasons-project.ru',
#  'parakazanmayollari.net',
#  'mykaplan.co.uk',
#  'generalsofarmageddon.com',
#  'pwcats.info',
#  'jysk.hu',
#  'bicolisarog.com',
#  'roundlinks.info',
#  'joj.sk',
#  'dncc.in',
#  'xn--80adakbyqm0agj9ira.xn--p1ai',
#  'momshoppingnetwork.com',
#  'iomint.sharepoint.com',
#  'saogoncalo.rn.gov.br',
#  'bccondos.net',
#  'prulifeuk.com.ph',
#  'sarkarischolarship.com',
#  'lascosasquenuncaexistieron.com',
#  'qhdsny.com',
#  'timlo.net',
#  'finya.de',
#  'innovation.gov.au',
#  'sorrelma.com',
#  'sandinist.livejournal.com',
#  'cont-plus.ru',
#  'qfsky.com',
#  'upei.ca',
#  'apkzz.com',
#  'senfinfo.com',
#  'techmobileprice.blogspot.com',
#  'judicial.gov.tw',
#  'shkaf-style.ru',
#  'haogang-rf.ru',
#  'alula-alula.livejournal.com',
#  'telema-service.com',
#  '12373116.cn',
#  'mitropolia-lip.ru',
#  'iran-door.ir',
#  'wetfeet.com',
#  'oraltubeporn.com',
#  'cenecuador.org',
#  'wphackedhelp.com',
#  'superiorpapers.com',
#  'quip-apple.com',
#  'zdruvotvet.ru',
#  'jsly001.com',
#  'chuyenthumuaxemaycu.com',
#  'maps-tel-aviv.com',
#  'baklatsidis.gr',
#  'cosmusbags.in',
#  'bryantschools.org',
#  'moto-service.ru',
#  'jsonquerytool.com',
#  'apartmani-crna-gora.me',
#  'quangsilic.com',
#  'diaocdothi.vn',
#  'car-teach.com',
#  'coral-poulithra.gr',
#  'planetrenders.net',
#  'balkon2dekor.ml',
#  'cpalsocial.org',
#  'widisudharta.weebly.com',
#  'hanshin-dept.jp',
#  'sarkarinaukriwar.com',
#  'karimoacademy.org',
#  'uploadsat.com',
#  'smarterclick.com',
#  'rediscoverdairy.co.za',
#  'jeweltheme.com',
#  'itoaki.com',
#  'awesem.com',
#  'uptoshort.me',
#  'wikislovo.ru',
#  'blomer.ru',
#  'rebatekey.com',
#  'chunker.com',
#  'smartsupp.com',
#  'flashscore.info',
#  'logolab.app',
#  'siaf.sg',
#  'torrentigruha.net',
#  'urbanmommies.com',
#  'xn----ftbnhpugkcecq.xn--p1ai',
#  'chobatdongsan.com.vn',
#  'binbirevimavm.com',
#  'icegate.gov.in',
#  'business-owners-club.com',
#  'levenrose.com',
#  'solgallery.ir',
#  'mdi.ac.in',
#  'internetically9.com',
#  'waizrahim.com',
#  'freedomcte.com',
#  'banehsearch.com',
#  'bloodandsoul.ru',
#  'simplyenergy.com.au',
#  'broprints.com',
#  'laingorourke.com',
#  'profil.dn.ua',
#  'halokerja.id',
#  'weathernews.com',
#  'lidolabs.com',
#  'androidp1.com',
#  'elevadorescompany.com',
#  'energia.gr',
#  'mohamed-hamed.com',
#  'chistyye-prudy-3.ru',
#  'i-know-now-plus.blogspot.com',
#  'organics4yourbaby.eu',
#  'spkmortgages.co.uk',
#  'hamrocompany.com',
#  'sntv.vn',
#  'xywjj.gov.cn',
#  'gyn700.com.tw',
#  'watchonlinemovies.vip',
#  'musorish.ru',
#  'gezerilaclama.com',
#  'lemontheme.com',
#  'totbroadband.com',
#  'iptime.org',
#  'fdp.sharepoint.com',
#  'atividadeseducacaoinfantil.com.br',
#  'steblovskiy.ru',
#  'scentworld.co',
#  'buscadordepalabras.com',
#  'similarworlds.com',
#  'abpservices.in',
#  'doemal.com',
#  'culamdi.com',
#  'jobsvision.co.in',
#  'b11wiki.org',
#  'elsanatlarivehobi.com',
#  'parliran.ir',
#  'disdiksmi.id',
#  'gmhs45.com',
#  'gogousenet.com',
#  'role-me.ru',
#  'liveprivates.com',
#  '365digital.co.za',
#  'nukesaq88.github.io',
#  'goodnet.gr',
#  'labranda.com',
#  'lustfulcoffee.com',
#  'supermiera.blogspot.com',
#  'testonlinespeed.com',
#  'weddingpark.net\r\r\n',
#  'zaums.ac.ir',
#  'radiokulmiye.net',
#  'thecampusconnect.com',
#  'webdesignbrasil.org',
#  'kesdi.com',
#  'elitecme.com',
#  'mydigitaloffice.lk',
#  'pickthumb.com',
#  'stom-m.ru',
#  'r2cgroup.com',
#  'cbbankcard.com',
#  'atriaclub.ru',
#  'galser.ru',
#  'permanentmakeuptattookit.com',
#  'swisslife.ch',
#  'koddostu.com',
#  'mitrabatavia.com',
#  'afrek.ru',
#  'kru-so.ru',
#  'bolupostasi.com',
#  ...]

# %%
len(result)
# Out:
# 17398
